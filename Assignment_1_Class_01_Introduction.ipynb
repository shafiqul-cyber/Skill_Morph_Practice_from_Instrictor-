# %% [markdown]
# <a href="https://colab.research.google.com/github/shafiqul-cyber/Skill_Morph_Practice_from_Instrictor-/blob/Skill_Morph/Class_01_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('welcome to skill morph!!')
# Out:
# welcome to skill morph!!

# %%
23+45
# Out:
# 68

# %% [markdown]
# # **Chapter-1**

# %% [markdown]
# ## **sub-chapter-1**
